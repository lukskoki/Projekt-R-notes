# %% [markdown]
# ## Data ingestion pipeline
#
# ### LangChain dokument
#
# 2 glavne komponente: page_content(str) i metadata(dict)
#
# #### Page content
# sadrzaj dokumenta, mora bit string. Treba pazit na velicinu, ako je veliki dokument, onda je bolje raspodjelit na chunks
#
# #### Metadata
# Dodatne informacije o dokumentu, koriste se za filtriranje, pracenje i kontekst.
# npr. izvor, timestamp, autor, jezik, chunk_id, itd.

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="neki sadrzaj",
    metadata = {
        "source": "izvor.txt",
        "pages": 1,
        "author": "Pero Peric",
        "date_created": "2025-01-01"
    }
)

doc
# Out:
# Document(metadata={'source': 'izvor.txt', 'pages': 1, 'author': 'Pero Peric', 'date_created': '2025-01-01'}, page_content='neki sadrzaj')

# %% [markdown]
# ### Ucitavanje tekst file-ova

# %%
## Text Loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("./data/clanak.txt", encoding='utf-8')
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': './data/clanak.txt'}, page_content='Šefica Podravke Martina Dalić je na društvenim mrežama objavila da je danas prodano svih 350 dionica Podravke koje je pogreškom kupila u vrijeme zabrane trgovanja.\n\nNapisala je da su dionice prodane po prosječnoj cijeni od 155,97 eura, a ostvarena zarada iznosi 157,5 eura. Taj iznos je, prema njezinim riječima, doniran Autonomnoj ženskoj kući Zagreb. Uz ovaj iznos Dalić im je donirala i dodatnih 2000 eura.\nDodala je da je ova kupnja, kao i ona koja se dogodila osobnom pogreškom, transparentno objavljena na stranicama Zagrebačke burze, Hine i Podravke.\n\nPodsjetimo, nakon što je šefica Podravke Martina Dalić prije dva tjedna kupila dionice Podravke po cijeni od 155,32 eura, danas ih je odlučila prodati. Kupila je 350 dionica po cijeni od 155,52 eura, što je izazvalo niz reakcija. Dalić je dionice kupila neposredno uoči objave poslovnih rezultata, a onda se javno ispričala na LinkedInu.\n')]

# %%
# Directory loader

from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    "./data",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding': 'utf-8'}
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': 'data\\clanak.txt'}, page_content='Šefica Podravke Martina Dalić je na društvenim mrežama objavila da je danas prodano svih 350 dionica Podravke koje je pogreškom kupila u vrijeme zabrane trgovanja.\n\nNapisala je da su dionice prodane po prosječnoj cijeni od 155,97 eura, a ostvarena zarada iznosi 157,5 eura. Taj iznos je, prema njezinim riječima, doniran Autonomnoj ženskoj kući Zagreb. Uz ovaj iznos Dalić im je donirala i dodatnih 2000 eura.\nDodala je da je ova kupnja, kao i ona koja se dogodila osobnom pogreškom, transparentno objavljena na stranicama Zagrebačke burze, Hine i Podravke.\n\nPodsjetimo, nakon što je šefica Podravke Martina Dalić prije dva tjedna kupila dionice Podravke po cijeni od 155,32 eura, danas ih je odlučila prodati. Kupila je 350 dionica po cijeni od 155,52 eura, što je izazvalo niz reakcija. Dalić je dionice kupila neposredno uoči objave poslovnih rezultata, a onda se javno ispričala na LinkedInu.\n')]

# %% [markdown]
# ### Ucitavanje svih pdf-a u direktoriju

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader # PyMuPDFLoader je bolja verzija od PyPDFLoader po brzini i nekim drugim metrikama

dir_loader = DirectoryLoader(
    "./data/pdf",
    loader_cls=PyMuPDFLoader,

)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 0}, page_content='Statistiˇcka analiza podataka\nUpute za rad na projektu i izradu izvjeˇstaja\nRad na projektu\nPri radu na projektu vaˇzna je komponenta timski rad – iako ´ce se uvijek na´ci kolege koji ´ce se znanjem i\ntrudom istaknuti u svakoj grupi, svakako preporuˇcujemo da ukljuˇcite sve kolege u rad grupe, budu´ci da\nje znanje cijele grupe bitno pri konaˇcnoj predaji. U samom radu na dodijeljenoj temi vaˇzno je imati na\numu sljede´ce:\n• Pregledajte datoteke s podatcima i naˇcin na koji su sami podatci uˇcitani u vaˇsu razvojnu okolinu\n(RStudio) – uvijek provjerite jesu li ispravno uˇcitani i postoje li kakvi sumnjivi unosi ili nedostaju´ce\nvrijednosti koje mogu utjecati na vaˇsu analizu.\n• Tijekom rada na projektu vizualizirajte podatke na razliˇcite naˇcine i analizirajte ono ˇsto vidite –\niako ne´ce sve vizualizacije nuˇzno u´ci u konaˇcni izvjeˇstaj, mogu vam biti korisne u analizi i vlastitim\nistraˇzivaˇckim pitanjima i hipotezama.\n• Istraˇzivaˇcke smjernice dane u opisu projekta su samo osnovne natuknice za izradu projekta – svakako\nrazmiˇsljajte i analizirajte vlastita istraˇzivaˇcka pitanja i hipoteze u svom projektu.\nIzvjeˇstaj\nSam izvjeˇstaj predajete u obliku .rmd datoteke koja sadrˇzi kod, rezultate i tekst, te .pdf datoteke koju\ngenerira RStudio kad pokrenete knit vaˇseg .rmd izvjeˇstaja. Takoder je nuˇzno predati sve datoteke koje\nsadrˇze medurezultate ili dodatne podatke potrebne za izvrˇsavanje koda vaˇseg projekta.\nPotrebno je\nda izvjeˇstaj sadrˇzi odredene deskriptivne analize i vizualizacije kojima moˇzete motivirati neke od vaˇsih\nanaliza, razliˇcite testove kojima biste neke od njih provjerili, te eventualne modele (npr. ANOVA ili\nregresija, ovisno o tome kakvim se podatcima bavite) kojima objaˇsnjavate razliˇcite efekte. Pri izradi\nizvjeˇstaja vodite se sljede´cim smjernicama:\n• Sam izvjeˇstaj sadrˇzi izmjenjuju´ce chunkove koda, rezultata (slike, tablice, ispisi iz razliˇcitih testova\ni analiza) i teksta. Sam tekst je nuˇzan kako biste povezali i objasnili ono ˇsto radite u kodu, ali\nnipoˇsto ne treba pisati previˇse (po par reˇcenica kod svakog dijela koda ili analize koje objaˇsnjavaju\nˇsto i zaˇsto radite te komentiraju rezultate).\n• U izvjeˇstaju preporuˇcujemo da pokuˇsate ˇsto viˇse povezati zajedniˇcku ”priˇcu” cijelog projekta.\nUpravo forma izvjeˇstaja kroz deskriptivnu analizu, vizualizaciju i statistiˇcke analize vam daje priliku\nda slijedno predstavite svoj projekt.\n• Sve ˇsto radite na projektu, kao i sve ˇsto ste pokuˇsavali ili isprobavali, ne mora nuˇzno biti u izvjeˇstaju\n– kljuˇcno je da odaberete one primjere koje ˇzelite prikazati u projektu (pritom nije dobro birati\nsamo one analize gdje su vaˇse hipoteze ”ispale” toˇcne - dapaˇce, dobro je pokazati i sluˇcajeve koji\nsu vas moˇzda posebno iznenadili i dati neku interpretaciju tome).\n1'),
#  Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 1}, page_content='• Iako nema minimalne i maksimalne duljine izvjeˇstaja (a i ona uvelike ovisi o koliˇcini slika, tablica\ni ispisa koje ´cete imati), ako vaˇs izvjeˇstaj ima previˇse ispisa koji su redundantni (npr. ispisi ili\nupozorenja iz nekih funkcija u R-u koji nisu nuˇzno dio analize), moˇzete sprijeˇciti njihov ispis u\nizvjeˇstaju, iako se funkcija izvrˇsava u kodu.\nKontrolna toˇcka i predaja projekta\nU sklopu izrade projekta postoji kontrolna toˇcka koja je obavezna za sve grupe i za sve njihove\nˇclanove. U tom trenutku ´ce svaka grupa sa svojim asistentom pro´ci kroz svoj projekt (odnosno ono ˇsto\ndo tog trenutka imate), a asistenti ´ce dati preporuke za proˇsirenje ili popravak projekta. Za uspjeˇsnu\nkontrolnu toˇcku svakako preporuˇcujemo da se pripremite s konkretnim pitanjima za asistente.\nNAPOMENA: Kontrolna toˇcka se ne ocjenjuje i sasvim je dopuˇsteno do´ci s potpuno praznim projektom\n(iako je i dalje obavezna) – no u tom sluˇcaju gubite priliku dobiti dubinski uvid u vaˇs projekt i savjete\nkako ga proˇsiriti ili poboljˇsati.\nOsim kontrolne toˇcke, asistenti su vam na raspolaganju za upite tijekom cijelog semestra – svakako\npreporuˇcujemo da iskoristite i tu priliku (no, na takvim konzultacijama asistenti mogu odgovarati na\nkonkretna pitanja – iz praktiˇcnih razloga ne mogu pregledavati vaˇse cijelo rjeˇsenje i traˇziti greˇske).\nPri predaji projekta asistenti ´ce zajedno sa svim ˇclanovima tima prolaziti kroz projektni izvjeˇstaj i\nnaizmjenice postavljati pitanja pojedinim ˇclanovima tima. Svi ˇclanovi tima moraju znati sve aspekte\nrjeˇsenja.\nPritom se ispituju i boduju: sam izvjeˇstaj, poznavanje koda (ˇsto se dogada u odredenim\ndijelovima koda i zaˇsto radite odredene analize – ˇsto njima ˇzelite pokazati) te poznavanje teorije u\npozadini metoda koje koristite (zaˇsto smijete ili ne smijete koristiti odredeni test, kako radi odredena\nmetoda itd.).\nStudenti ˇcesto znaju proˇsiriti osnovni skup metoda i alata iz SAP-a i koristiti i neke\nnaprednije metode u svojim analizama – to nipoˇsto nije zabranjeno, ali imajte na umu da vas asistenti\nmogu ispitati sve ˇsto koristite u projektu, pa tako i teoretske pozadine svih metoda koje koristite.\nZa sva pitanja tijekom rada na projektu svakako se obratite asistentima.\nˇZelimo vam uspjeˇsan rad na projektu.\n2'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page':
),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 10}, page_content='11 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nProvjera znanja i određivanje ocjene\nLaboratorijske vježbe\n•\nVoditelj grupe koja se odlučila za projektni zadatak prijavljuje \nčlanove svoje grupe preko Google obrasca (link u obavijesti na \nwebu) najkasnije do roka za predaju prve laboratorijske vježbe\n•\nZa ostale studente pretpostavlja se da rješavaju lakšu inačicu LV\n•\nPredaja i vrednovanje na sustavu SPRUT (vrijedi za oba oblika LV)\n•\nDo roka koji odrede nastavnici u obavijesti na webu\n•\nPredaja nakon krajnjeg roka nije moguća\n•\nTijekom izrade rješenja, na raspolaganju je dio ispitnih primjera\n•\nTijekom vrednovanja, dodaju se novi ispitni primjeri\n•\nRješenja za težu inačicu LV predaje samo voditelj grupe\n1) Kontinuirana provjera znanja'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 11}, page_content='12 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nProvjera znanja i određivanje ocjene\nUkupno teorija + praksa\n•\n100 ili 80 bodova\n•\novisi o tome je li izabran zahtjevniji ili jednostavniji oblik \nlaboratorijskih vježbi\nBodovni pragovi\n•\nza dobivanje pozitivne ocjene\n•\nprag iz teorijskog dijela ocjene\n30/60 bodova (50%)\n•\nprag iz praktičnog dijela ocjene\n10/20 ili 20/40 bodova (50%)\nOdređivanje ocjene\n•\ndovoljan (2)\n \n40 ili 50 bodova (ovisno o izboru lab. vj.)\n•\ndobar (3)\n63 bodova\n•\nvrlo dobar (4) \n75 bodova\n•\nizvrstan (5)\n88 bodova\n1) Kontinuirana provjera znanja'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 12}, page_content='13 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nProvjera znanja i određivanje ocjene\nPismeni ispit\n•\n100 bodova\nBodovni pragovi za izlazak na ispitni rok\n•\nprag iz praktičnog dijela ocjene: 10/20 ili 20/40 bodova (50%)\n•\nne ulazi u ocjenu pismenog ispita\nOdređivanje ocjene\n•\ndovoljan (2)\n50 bodova\n•\ndobar (3)\n63 bodova\n•\nvrlo dobar (4)\n75 bodova\n•\nizvrstan (5)\n88 bodova\n2) Ispitni rok')]

# %% [markdown]
# ### Chunking
#
# RecursiveCharacterTextSplitter ce nam omogucit da dokumente podjelimo u chunks.
#
# On najprije pokusa razdvojit dokument po velikim separatorima poput \n, \n\n, itd. A ako to ne uspije onda predodredimo koliki chunk size da bude pa on odreze dokument i usred recenice ako je preslo npr. 1000 znakova

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
# RecursiveCharacterTextSplitter ce nam omofucit da dokumente podjelimo u chunks


def split_documents(documents, chunk_size=1000,chunk_overlap=200):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        separators=["\n\n", "\n", " ", ""]
    )

    split_docs = text_splitter.split_documents(documents)
    print(f"Splitao {len(documents)} dokumenta u {len(split_docs)} chunkova")

    if split_docs:
        print(f"Primjer chunk-a: ")
        print(f"Content: {split_docs[0].page_content[:200]}")
        print(f"Metadata: {split_docs[0].metadata}")

    
    return split_docs

# %%
chunks = split_documents(pdf_documents)
# Out:
# Splitao 15 dokumenta u 20 chunkova
# Primjer chunk-a:
# Content: Statistiˇcka analiza podataka
# Upute za rad na projektu i izradu izvjeˇstaja
# Rad na projektu
# Pri radu na projektu vaˇzna je komponenta timski rad – iako ´ce se uvijek na´ci kolege koji ´ce se znanjem i
# Metadata: {'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 0}

# %%
chunks
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 0}, page_content='Statistiˇcka analiza podataka\nUpute za rad na projektu i izradu izvjeˇstaja\nRad na projektu\nPri radu na projektu vaˇzna je komponenta timski rad – iako ´ce se uvijek na´ci kolege koji ´ce se znanjem i\ntrudom istaknuti u svakoj grupi, svakako preporuˇcujemo da ukljuˇcite sve kolege u rad grupe, budu´ci da\nje znanje cijele grupe bitno pri konaˇcnoj predaji. U samom radu na dodijeljenoj temi vaˇzno je imati na\numu sljede´ce:\n• Pregledajte datoteke s podatcima i naˇcin na koji su sami podatci uˇcitani u vaˇsu razvojnu okolinu\n(RStudio) – uvijek provjerite jesu li ispravno uˇcitani i postoje li kakvi sumnjivi unosi ili nedostaju´ce\nvrijednosti koje mogu utjecati na vaˇsu analizu.\n• Tijekom rada na projektu vizualizirajte podatke na razliˇcite naˇcine i analizirajte ono ˇsto vidite –\niako ne´ce sve vizualizacije nuˇzno u´ci u konaˇcni izvjeˇstaj, mogu vam biti korisne u analizi i vlastitim\nistraˇzivaˇckim pitanjima i hipotezama.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 0}, page_content='iako ne´ce sve vizualizacije nuˇzno u´ci u konaˇcni izvjeˇstaj, mogu vam biti korisne u analizi i vlastitim\nistraˇzivaˇckim pitanjima i hipotezama.\n• Istraˇzivaˇcke smjernice dane u opisu projekta su samo osnovne natuknice za izradu projekta – svakako\nrazmiˇsljajte i analizirajte vlastita istraˇzivaˇcka pitanja i hipoteze u svom projektu.\nIzvjeˇstaj\nSam izvjeˇstaj predajete u obliku .rmd datoteke koja sadrˇzi kod, rezultate i tekst, te .pdf datoteke koju\ngenerira RStudio kad pokrenete knit vaˇseg .rmd izvjeˇstaja. Takoder je nuˇzno predati sve datoteke koje\nsadrˇze medurezultate ili dodatne podatke potrebne za izvrˇsavanje koda vaˇseg projekta.\nPotrebno je\nda izvjeˇstaj sadrˇzi odredene deskriptivne analize i vizualizacije kojima moˇzete motivirati neke od vaˇsih\nanaliza, razliˇcite testove kojima biste neke od njih provjerili, te eventualne modele (npr. ANOVA ili\nregresija, ovisno o tome kakvim se podatcima bavite) kojima objaˇsnjavate razliˇcite efekte. Pri izradi'),
#  Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 0}, page_content='regresija, ovisno o tome kakvim se podatcima bavite) kojima objaˇsnjavate razliˇcite efekte. Pri izradi\nizvjeˇstaja vodite se sljede´cim smjernicama:\n• Sam izvjeˇstaj sadrˇzi izmjenjuju´ce chunkove koda, rezultata (slike, tablice, ispisi iz razliˇcitih testova\ni analiza) i teksta. Sam tekst je nuˇzan kako biste povezali i objasnili ono ˇsto radite u kodu, ali\nnipoˇsto ne treba pisati previˇse (po par reˇcenica kod svakog dijela koda ili analize koje objaˇsnjavaju\nˇsto i zaˇsto radite te komentiraju rezultate).\n• U izvjeˇstaju preporuˇcujemo da pokuˇsate ˇsto viˇse povezati zajedniˇcku ”priˇcu” cijelog projekta.\nUpravo forma izvjeˇstaja kroz deskriptivnu analizu, vizualizaciju i statistiˇcke analize vam daje priliku\nda slijedno predstavite svoj projekt.\n• Sve ˇsto radite na projektu, kao i sve ˇsto ste pokuˇsavali ili isprobavali, ne mora nuˇzno biti u izvjeˇstaju\n– kljuˇcno je da odaberete one primjere koje ˇzelite prikazati u projektu (pritom nije dobro birati'),
#  Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 0}, page_content='– kljuˇcno je da odaberete one primjere koje ˇzelite prikazati u projektu (pritom nije dobro birati\nsamo one analize gdje su vaˇse hipoteze ”ispale” toˇcne - dapaˇce, dobro je pokazati i sluˇcajeve koji\nsu vas moˇzda posebno iznenadili i dati neku interpretaciju tome).\n1'),
#  Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 1}, page_content='• Iako nema minimalne i maksimalne duljine izvjeˇstaja (a i ona uvelike ovisi o koliˇcini slika, tablica\ni ispisa koje ´cete imati), ako vaˇs izvjeˇstaj ima previˇse ispisa koji su redundantni (npr. ispisi ili\nupozorenja iz nekih funkcija u R-u koji nisu nuˇzno dio analize), moˇzete sprijeˇciti njihov ispis u\nizvjeˇstaju, iako se funkcija izvrˇsava u kodu.\nKontrolna toˇcka i predaja projekta\nU sklopu izrade projekta postoji kontrolna toˇcka koja je obavezna za sve grupe i za sve njihove\nˇclanove. U tom trenutku ´ce svaka grupa sa svojim asistentom pro´ci kroz svoj projekt (odnosno ono ˇsto\ndo tog trenutka imate), a asistenti ´ce dati preporuke za proˇsirenje ili popravak projekta. Za uspjeˇsnu\nkontrolnu toˇcku svakako preporuˇcujemo da se pripremite s konkretnim pitanjima za asistente.\nNAPOMENA: Kontrolna toˇcka se ne ocjenjuje i sasvim je dopuˇsteno do´ci s potpuno praznim projektom'),
#  Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 1}, page_content='kontrolnu toˇcku svakako preporuˇcujemo da se pripremite s konkretnim pitanjima za asistente.\nNAPOMENA: Kontrolna toˇcka se ne ocjenjuje i sasvim je dopuˇsteno do´ci s potpuno praznim projektom\n(iako je i dalje obavezna) – no u tom sluˇcaju gubite priliku dobiti dubinski uvid u vaˇs projekt i savjete\nkako ga proˇsiriti ili poboljˇsati.\nOsim kontrolne toˇcke, asistenti su vam na raspolaganju za upite tijekom cijelog semestra – svakako\npreporuˇcujemo da iskoristite i tu priliku (no, na takvim konzultacijama asistenti mogu odgovarati na\nkonkretna pitanja – iz praktiˇcnih razloga ne mogu pregledavati vaˇse cijelo rjeˇsenje i traˇziti greˇske).\nPri predaji projekta asistenti ´ce zajedno sa svim ˇclanovima tima prolaziti kroz projektni izvjeˇstaj i\nnaizmjenice postavljati pitanja pojedinim ˇclanovima tima. Svi ˇclanovi tima moraju znati sve aspekte\nrjeˇsenja.\nPritom se ispituju i boduju: sam izvjeˇstaj, poznavanje koda (ˇsto se dogada u odredenim'),
#  Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-14T11:09:17+00:00', 'source': 'data\\pdf\\sap.pdf', 'file_path': 'data\\pdf\\sap.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-14T11:09:17+00:00', 'trapped': '', 'modDate': 'D:20241014110917Z', 'creationDate': 'D:20241014110917Z', 'page': 1}, page_content='rjeˇsenja.\nPritom se ispituju i boduju: sam izvjeˇstaj, poznavanje koda (ˇsto se dogada u odredenim\ndijelovima koda i zaˇsto radite odredene analize – ˇsto njima ˇzelite pokazati) te poznavanje teorije u\npozadini metoda koje koristite (zaˇsto smijete ili ne smijete koristiti odredeni test, kako radi odredena\nmetoda itd.).\nStudenti ˇcesto znaju proˇsiriti osnovni skup metoda i alata iz SAP-a i koristiti i neke\nnaprednije metode u svojim analizama – to nipoˇsto nije zabranjeno, ali imajte na umu da vas asistenti\nmogu ispitati sve ˇsto koristite u projektu, pa tako i teoretske pozadine svih metoda koje koristite.\nZa sva pitanja tijekom rada na projektu svakako se obratite asistentima.\nˇZelimo vam uspjeˇsan rad na projektu.\n2'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 0}, page_content='1 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nPrevođenje programskih jezika\nhttp://www.fer.unizg.hr/predmet/ppj\nppj@fer.hr\nProf. dr. sc. Dejan Škvorc\nIzv. prof. dr. sc. Marin Šilić\nIzv. prof. dr. sc. Goran Delač\nIzv. prof. dr. sc. Klemo Vladimir\nDoc. dr. sc. Adrian Satja Kurdija\nFakultet elektrotehnike i računarstva\nSveučilište u Zagrebu'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 1}, page_content='2 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nNastavnici i opterećenje\nPredavači\nProf. dr. sc. Dejan Škvorc\nIzv. prof. dr. sc. Marin Šilić\nIzv. prof. dr. sc. Goran Delač\nIzv. prof. dr. sc. Klemo Vladimir\nDoc. dr. sc. Adrian Satja Kurdija\nAsistenti\nStjepan Požgaj, mag. inf. et math.\nECTS: 5\nOblik nastave\nOpterećenje\nPredavanja\n60\nLaboratorijske vježbe\n10'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 2}, page_content='3 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nLiteratura\nS. Srbljić\nPrevođenje programskih jezika\nUdžbenik Sveučilišta u Zagrebu, Element, \nZagreb 2007.\nS. Srbljić\nJEZIČNI PROCESORI 2:\nAnaliza izvornog i sinteza ciljnog programa\nUdžbenik Sveučilišta u Zagrebu, Element, \nZagreb 2002.\nhttp://www.element.hr/'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 3}, page_content='4 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 4}, page_content='5 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nRed predavanja\nPRVI CIKLUS NASTAVE\n1. tjedan\nPREDAVANJE 1, 2\n2. tjedan\nPREDAVANJE 3, 4\n3. tjedan\nPREDAVANJE 5, 6\n4. tjedan\nPREDAVANJE 7, 8\nUVOD\nLEKSIČKA ANALIZA\nSINTAKSNA ANALIZA \n(1/3)\nSINTAKSNA \nANALIZA \n(2/3)\n5. tjedan\nPREDAVANJE 9, 10\n6. tjedan\nPREDAVANJE 11, 12\n7. tjedan\nAUDITORNE VJEŽBE\nMEĐUISPIT\nSINTAKSNA \nANALIZA \n(3/3)\nSEMANTIČKA \nANALIZA\n(1/3)\nSEMANTIČKA \nANALIZA\n(2/3)\nPRIPREMA ZA\nMEĐUISPIT:\nleksička,\nsintaksna\ni semantička\nanaliza\nleksička, sintaksna i \ndio semantičke\nanalize'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 5}, page_content='6 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nRed predavanja\nDRUGI CIKLUS NASTAVE\n8. tjedan\nPREDAVANJE 13,14\n9. tjedan\nPREDAVANJE 15,16\n10. tjedan\nPREDAVANJE 17,18\n11. tjedan\nPREDAVANJE 19,20\nSEMANTIČKA \nANALIZA\n(3/3)\nPOTPORA IZVOĐ.\nCILJNOG PROG. \n(1/2)\nPOTPORA IZVOĐ.\nCILJNOG PROG. (2/2)\nGENERIRANJE\nMEĐUKODA (1/2)\nGENERIRANJE\nMEĐUKODA (2/2)\nGENERIRANJE\nCILJNOG\nPROGRAMA\nOPTIMIRANJE (1/2)\n12. tjedan\nPREDAVANJE 21\n13. tjedan\nAUDITORNE VJEŽBE\nZAVRŠNI ISPIT\nOPTIMIRANJE (2/2)\nPRIPREMA ZA\nZAVRŠNI ISPIT:\npotpora izvođenju,\ngeneriranje i\noptimiranje\nciljnog programa\nCJELOKUPNO GRADIVO\nPREDMETA'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 6}, page_content='7 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nProvjera znanja i određivanje ocjene\nTeorijski dio ocjene\n•\nMeđuispit \n25 bodova\n•\nZavršni ispit \n \n25 bodova\n•\nPrisutnost na predavanjima*\n10 bodova\n•\nUkupno\n60 bodova\nPraktični dio ocjene\n•\nLaboratorijske vježbe (dvije mogućnosti, student izabire jednu)\n•\nSamostalni rad, lakši zadaci   \n20 bodova\nili\n•\nSamostalni rad ili u paru,\nzahtjevan projektni zadatak  \n \n40 bodova\n•\nUkupno\n20 ili 40 bodova\n1) Kontinuirana provjera znanja\n* Moguće su povremene i nenajavljene provjere popisa studenata, s mogućnošću smanjenja, \noduzimanja i/ili dodjele negativnih bodova u slučaju ustanovljenog nesklada između popisa i \nzatečenog stanja u dvorani.'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page':
),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 11}, page_content='12 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nProvjera znanja i određivanje ocjene\nUkupno teorija + praksa\n•\n100 ili 80 bodova\n•\novisi o tome je li izabran zahtjevniji ili jednostavniji oblik \nlaboratorijskih vježbi\nBodovni pragovi\n•\nza dobivanje pozitivne ocjene\n•\nprag iz teorijskog dijela ocjene\n30/60 bodova (50%)\n•\nprag iz praktičnog dijela ocjene\n10/20 ili 20/40 bodova (50%)\nOdređivanje ocjene\n•\ndovoljan (2)\n \n40 ili 50 bodova (ovisno o izboru lab. vj.)\n•\ndobar (3)\n63 bodova\n•\nvrlo dobar (4) \n75 bodova\n•\nizvrstan (5)\n88 bodova\n1) Kontinuirana provjera znanja'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': '', 'creationdate': '2025-10-01T13:31:49+02:00', 'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'total_pages': 13, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20251001133149+02'00", 'page': 12}, page_content='13 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nProvjera znanja i određivanje ocjene\nPismeni ispit\n•\n100 bodova\nBodovni pragovi za izlazak na ispitni rok\n•\nprag iz praktičnog dijela ocjene: 10/20 ili 20/40 bodova (50%)\n•\nne ulazi u ocjenu pismenog ispita\nOdređivanje ocjene\n•\ndovoljan (2)\n50 bodova\n•\ndobar (3)\n63 bodova\n•\nvrlo dobar (4)\n75 bodova\n•\nizvrstan (5)\n88 bodova\n2) Ispitni rok')]

# %% [markdown]
# ### Embeddings
#
# Kad smo tekst podjelili u chunkove, mozemo prijeci na embeddanje teksta u vektore.
#
# Kao sto sam i u chroma testu napravio pomocu openAi embeddings modela, tako cu i tu.

# %%
import numpy as np
import chromadb
import uuid
from typing import List, Dict, Any, Tuple
from sklearn.metrics.pairwise import cosine_similarity 
from dotenv import load_dotenv
import os
import openai
load_dotenv()

KEY=os.getenv('API_KEY')

# %%
import chromadb.utils.embedding_functions as embedding_functions
openai_ef = embedding_functions.OpenAIEmbeddingFunction(
    api_key=KEY,
    model_name="text-embedding-3-small"
)

contents = [x.page_content for x in chunks] # Dobijemo clanke iz dokumenta
contents

embeddings = openai_ef(contents)

# %%
client = chromadb.PersistentClient(path="./vectordb")

collection = client.create_collection(name="predmeti")

# %%
def add_documents(documents, embeddings, collection):
    # funkcija za dodavanje dokumenata u kolekciju

    # documents je lista tipa Document

    if len(documents) != len(embeddings):
        raise ValueError("Broj dokumenata se mora podudarat sa brojem embeddinga")
    
    ids = []
    metadatas=[]
    documents_text=[]
    embeddings_list = []

    for i ,(doc, embedding) in enumerate(zip(documents, embeddings)):
        doc_id = f"doc_{uuid.uuid4().hex[:8]}_{i}"
        ids.append(doc_id)

        metadata=dict(doc.metadata)
        metadata['doc_index'] = i
        metadata['content_length'] = len(doc.page_content)
        metadatas.append(metadata)

        documents_text.append(doc.page_content)

        embeddings_list.append(embedding.tolist())
    
    try:
        collection.add(
            ids=ids,
            embeddings=embeddings_list,
            metadatas=metadatas,
            documents=documents_text
        )

    except Exception as e:
        print("error kod dodavanja dokumenta u collection")
        print(e)


    return collection

collection2 = add_documents(chunks, embeddings, collection)

print(collection2)
# Out:
# Collection(name=predmeti)

# %%
user_query = "Kad je kontrolna tocka"
query_embedded = openai_ef([user_query])
context = collection2.query(
    query_embeddings=query_embedded,
    n_results=3
)
print(context['documents'][0][0])
# Out:
# • Iako nema minimalne i maksimalne duljine izvjeˇstaja (a i ona uvelike ovisi o koliˇcini slika, tablica
# i ispisa koje ´cete imati), ako vaˇs izvjeˇstaj ima previˇse ispisa koji su redundantni (npr. ispisi ili
# upozorenja iz nekih funkcija u R-u koji nisu nuˇzno dio analize), moˇzete sprijeˇciti njihov ispis u
# izvjeˇstaju, iako se funkcija izvrˇsava u kodu.
# Kontrolna toˇcka i predaja projekta
# U sklopu izrade projekta postoji kontrolna toˇcka koja je obavezna za sve grupe i za sve njihove
# ˇclanove. U tom trenutku ´ce svaka grupa sa svojim asistentom pro´ci kroz svoj projekt (odnosno ono ˇsto
# do tog trenutka imate), a asistenti ´ce dati preporuke za proˇsirenje ili popravak projekta. Za uspjeˇsnu
# kontrolnu toˇcku svakako preporuˇcujemo da se pripremite s konkretnim pitanjima za asistente.
# NAPOMENA: Kontrolna toˇcka se ne ocjenjuje i sasvim je dopuˇsteno do´ci s potpuno praznim projektom

# %% [markdown]
# S ovime smo napravili cjeli data ingestion pipeline.
#
# Koristili smo LangChain za ucitavanje podataka iz pdf-a, teksta i ostlih sadrzaja. Taj tekst smo onda pretvorili u chunks i kasnije proveli embedding te vektore zapisali u vektorsku bazu pomocu chromadb

# %% [markdown]
# ## Retrieval Pipeline
#
# Sad mozemo krenut s drugim pipeline-om, a to je Retrieval, s kojim cemo handleat user_queries i doobavljanje iz vektorske baze

# %%
class RAGRetriever:

    def __init__(self, collection):

        self.collection=collection
        print('kolekcija: ', collection)

    def retrieve(self, query, top_k=5, score_threshold=0.0):
        # Vrati relevantne dokumente na temelju query-a

        query_embedding = openai_ef([query])[0]

        try:
            results=collection.query(
                query_embeddings=[query_embedding],
                n_results=top_k
            )

            retrieved = []

            if results['documents'] and results['documents'][0]:
                # Stavljamo [0], zato sto se vraca u formatu [[]], pa da dobijemo pravu listu
                documents = results['documents'][0]
                metadatas = results['metadatas'][0]
                distances = results['distances'][0]
                ids = results['ids'][0]

                for i, (doc_id, document, metadata, distance) in enumerate(zip(ids, documents, metadatas, distances)):
                    similarity_score = 1/(1+distance) # ChromaDB koristi squared L2 distance da izracuna udaljenost
                    # 1/(1+distance) dobimo normaliziranu vrijednost izmedu 0 i 1

                
                    retrieved.append({
                        "id": doc_id,
                        "content": document,
                        "metadata": metadata,
                        "similarity_score": similarity_score,
                        'distance': distance,
                        'rank': i + 1
                    })

                print(f"Vratio {len(retrieved)} dokumenata nakon filtriranja")
            else:
                print("nema dokumenata")

            return retrieved
        
        except Exception as e:
            print(f"error kod dobavljanja dokumenata: {e}")
            return []

# %%
rag_retriever = RAGRetriever(collection2)
# Out:
# kolekcija:  Collection(name=predmeti)

# %%
test = rag_retriever.retrieve(query="Koji su predavaci za predmet PPJ")
test[0]
# Vidimo u content da se vratio ispravan chunk
# Out:
# Vratio 5 dokumenata nakon filtriranja
# {'id': 'doc_fa6e2b3d_8',
#  'content': '2 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nNastavnici i opterećenje\nPredavači\nProf. dr. sc. Dejan Škvorc\nIzv. prof. dr. sc. Marin Šilić\nIzv. prof. dr. sc. Goran Delač\nIzv. prof. dr. sc. Klemo Vladimir\nDoc. dr. sc. Adrian Satja Kurdija\nAsistenti\nStjepan Požgaj, mag. inf. et math.\nECTS: 5\nOblik nastave\nOpterećenje\nPredavanja\n60\nLaboratorijske vježbe\n10',
#  'metadata': {'keywords': '',
#   'creator': '',
#   'modDate': '',
#   'title': '',
#   'author': '',
#   'producer': 'cairo 1.18.0 (https://cairographics.org)',
#   'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf',
#   'page': 1,
#   'content_length': 382,
#   'file_path': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf',
#   'subject': '',
#   'doc_index': 8,
#   'total_pages': 13,
#   'creationDate': "D:20251001133149+02'00",
#   'creationdate': '2025-10-01T13:31:49+02:00',
#   'trapped': '',
#   'moddate': '',
#   'format': 'PDF 1.7'},
#  'similarity_score': 0.5339857825450229,
#  'distance': 0.8727090358734131,
#  'rank': 1}

# %% [markdown]
# ### LLM Output
#
# Tu cemo spojit LLM te mu poslat kontekst iz vektorse baze

# %%
from langchain_openai import ChatOpenAI
# langchain ima integraciju sa openai pa mozemo samo api key staviti u njega
KEY=os.getenv('API_KEY')
llm = ChatOpenAI(model="gpt-4o-mini", api_key=KEY, temperature=0.1, model_kwargs={"max_tokens": 1024})
# Temperature oznacava koliko llm odstupa od najvjerojatnijeg tokena
# Ja sam stavio niski jer zelim smanjit halucinacije

# Napravimo RAG funkciju koja ce sve spojit
def rag(query, retriever, llm, top_k=3):

    result = retriever.retrieve(query, top_k=top_k)

    # Slozimo kontekst za LLM
    context = "\n\n".join([doc['content'] for doc in result]) if result else ""

    if not context:
        return "Nema relevantnog konteksta"
    
    # Generiramo odgovr sa LLM-om

    prompt = f"""
        You are a helpful assistant to students who want to find out information about their University, classes and other University related topics.
        Speak in Croatian.
        As a data source use only the context provided in this prompt.
        Speak in a helpful tone and offer your help.

        Context:
        {context}

        Question: {query}
         """
    
    response = llm.invoke([prompt.format(context=context, query=query)])

    return response.content
# Out:
# c:\Users\Korisnik\OneDrive\Radna površina\5.semestar\pror\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3639: UserWarning: Parameters {'max_tokens'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if await self.run_code(code, result, async_=asy):

# %%
answer = rag("Koja je minimalna duljina izvjestaja?", rag_retriever, llm)
print(answer)
# Out:
# Vratio 3 dokumenata nakon filtriranja
# Iako nema minimalne duljine izvještaja, važno je da izvještaj bude jasan i sažet. Preporučuje se da se izbjegne previše redundantnih ispisa i da se fokusirate na bitne informacije. Ako imate dodatnih pitanja ili trebate pomoć oko izrade izvještaja, slobodno pitajte!

# %% [markdown]
# ### Poboljsani RAG pipeline

# %%
def rag_advanced(query, retriever, llm, top_k=5, min_score=0.2, return_context=False):
    result = retriever.retrieve(query, top_k=top_k, score_threshold = min_score)

    if not result:
        return {'answer': "Nema relevantnog konteksta", 'sources': [], 'confidence': 0.0, 'context': ''}
    
    context = "\n\n".join([doc['content'] for doc in result])

    sources = [{
        'source': doc['metadata'].get('source', doc['metadata'].get('source', 'unknown')),
        'page': doc['metadata'].get("page", "unknown"),
        'score': doc['similarity_score'],
        'preview': doc['content'][:120] + '...'
        } for doc in result]
    
    confidence = max([doc['similarity_score'] for doc in result])

    prompt = f"""
        You are a helpful assistant to students who want to find out information about their University, classes and other University related topics.
        Speak in Croatian.
        As a data source use only the context provided in this prompt.
        Speak in a helpful tone and offer your help.

        Context:
        {context}

        Question: {query}
         """
    
    response = llm.invoke([prompt.format(context=context, query=query)])

    output = {
        'answer': response.content,
        'sources': sources,
        'confidence': confidence
    }

    if return_context:
        output['context'] = context

    return output

# %%
result = rag_advanced("Sto se radi na predmetu PPJ?", rag_retriever, llm, top_k=3, min_score=0.1, return_context=True)


print("Answer: ", result['answer'])
print("Sources: ", result['sources'])
print("Confidence: ", result['confidence'])
print("Context preview: ", result['context'][:300])
# Out:
# Vratio 3 dokumenata nakon filtriranja
# Answer:  Na predmetu "Prevođenje programskih jezika" (PPJ) studenti se bave raznim aspektima razvoja jezičnih procesora. Tijekom nastave, fokusira se na semantičku analizu, generiranje međukoda i ciljnog programa, te optimizaciju. Predavanja su organizirana u blokovima, a studenti sudjeluju u laboratorijskim vježbama gdje rade na zahtjevnim projektnim zadacima u grupama.
#
# Također, postoji kontinuirana provjera znanja koja uključuje rad u grupi, projektne zadatke, te usmena ispitivanja kako bi se provjerio pojedinačni doprinos članova grupe. Ako imate dodatnih pitanja ili trebate više informacija o predmetu, slobodno pitajte!
# Sources:  [{'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'page': 5, 'score': 0.5266247988025364, 'preview': '6 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nRed predavanja\nDRUGI CIKLUS NASTAVE\n8. tjedan\nP...'}, {'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'page': 8, 'score': 0.5228854252075589, 'preview': '9 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nProvjera znanja i određivanje ocjene\nLaboratori...'}, {'source': 'data\\pdf\\UNIZG-FER-PPJ-Uvodno.pdf', 'page': 9, 'score': 0.5226488751309253, 'preview': '10 od 68\nCopyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika\nProvjera znanja i određivanje ocjene\nLaborator...'}]
# Confidence:  0.5266247988025364
# Context preview:  6 od 68
# Copyright © 2020 S.Srbljić et al.: Prevođenje programskih jezika
# Red predavanja
# DRUGI CIKLUS NASTAVE
# 8. tjedan
# PREDAVANJE 13,14
# 9. tjedan
# PREDAVANJE 15,16
# 10. tjedan
# PREDAVANJE 17,18
# 11. tjedan
# PREDAVANJE 19,20
# SEMANTIČKA
# ANALIZA
# (3/3)
# POTPORA IZVOĐ.
# CILJNOG PROG.
# (1/2)
# POTPORA IZVOĐ.
# CILJ

# %% [markdown]
# ## Zakljucak
#
# S ovime sam prosao cjeli RAG pipeline uz pomoc LangChain i ChromaDB.
#
# 1. Data ingestion pipeline
# Ucitavanje podataka uz PyMuPDFLoader i DirectoryLoader.
# Chunking sa RecursiveCharacterTextSplitter za djeljenje dokumenata u manje dijelove.
# Embeddanje sa OpenAI modelom.
# ChromaDB PersistentClient za pohranu vektora lokalno u bazu.
# ChromaDB collections za pohranu dokumenata, njihovih embeddinga i meta podataka. Takoder se koristi i za queryanje.
#
# 2. Retrieval pipeline
# RagRetriever klasa koji uzme user query, napravi embedding i dohvati relevantne podatke. Vraca njihov metadata i content. Takoder racuna i similarity score.
#
# 3. Generation
# Na kraju imamo i rag_advanced funkciju koja prima RagRetriever klasu, user query i ostale metrike.
# Dohvaca relevantne podatke te salje prompt LLM-u sa dohvacenim kontekstom.
# LLM generira odgovor i on se prikazuje korisniku
